# %%
import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS = 3
EPOCHS = 25

# %%
# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    validation_split=0.2
)

# %%
train_generator = train_datagen.flow_from_directory(
    "Tomato",
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
)
# Out:
# Found 12813 images belonging to 10 classes.

# %%
validation_generator = train_datagen.flow_from_directory(
    "Tomato",
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
)
# Out:
# Found 3198 images belonging to 10 classes.

# %%
class_names = train_generator.class_indices
print(class_names)
# Out:
# {'Tomato_Bacterial_spot': 0, 'Tomato_Early_blight': 1, 'Tomato_Late_blight': 2, 'Tomato_Leaf_Mold': 3, 'Tomato_Septoria_leaf_spot': 4, 'Tomato_Spider_mites_Two_spotted_spider_mite': 5, 'Tomato__Target_Spot': 6, 'Tomato__Tomato_YellowLeaf__Curl_Virus': 7, 'Tomato__Tomato_mosaic_virus': 8, 'Tomato_healthy': 9}

# %%
# Model Definition
model = models.Sequential([
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS)),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(len(class_names), activation='softmax'),
])

# %%
# Model Compilation
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Model Training
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    epochs=EPOCHS
)
# Out:
# Epoch 1/25
# 400/400 [==============================] - 328s 818ms/step - loss: 1.5768 - accuracy: 0.4414 - val_loss: 1.2193 - val_accuracy: 0.5941
# Epoch 2/25
# 400/400 [==============================] - 332s 830ms/step - loss: 0.9363 - accuracy: 0.6747 - val_loss: 0.7459 - val_accuracy: 0.7456
# Epoch 3/25
# 400/400 [==============================] - 328s 820ms/step - loss: 0.7011 - accuracy: 0.7587 - val_loss: 0.5530 - val_accuracy: 0.8021
# Epoch 4/25
# 400/400 [==============================] - 332s 830ms/step - loss: 0.5446 - accuracy: 0.8069 - val_loss: 0.4704 - val_accuracy: 0.8292
# Epoch 5/25
# 400/400 [==============================] - 332s 829ms/step - loss: 0.4800 - accuracy: 0.8305 - val_loss: 0.4630 - val_accuracy: 0.8387
# Epoch 6/25
# 400/400 [==============================] - 330s 825ms/step - loss: 0.4235 - accuracy: 0.8523 - val_loss: 0.5338 - val_accuracy: 0.8147
# Epoch 7/25
# 400/400 [==============================] - 330s 825ms/step - loss: 0.3706 - accuracy: 0.8702 - val_loss: 0.3322 - val_accuracy: 0.8939
# Epoch 8/25
# 400/400 [==============================] - 327s 817ms/step - loss: 0.3325 - accuracy: 0.8851 - val_loss: 0.3250 - val_accuracy: 0.8870
# Epoch 9/25
# 400/400 [==============================] - 329s 821ms/step - loss: 0.3134 - accuracy: 0.8934 - val_loss: 0.2826 - val_accuracy: 0.9015
# Epoch 10/25
# 400/400 [==============================] - 327s 817ms/step - loss: 0.2789 - accuracy: 0.9043 - val_loss: 0.3021 - val_accuracy: 0.9003
# Epoch 11/25
# 400/400 [==============================] - 331s 828ms/step - loss: 0.2594 - accuracy: 0.9114 - val_loss: 0.2316 - val_accuracy: 0.9242
# Epoch 12/25
# 400/400 [==============================] - 331s 827ms/step - loss: 0.2417 - accuracy: 0.9180 - val_loss: 0.2884 - val_accuracy: 0.8990
# Epoch 13/25
# 400/400 [==============================] - 332s 830ms/step - loss: 0.2315 - accuracy: 0.9203 - val_loss: 0.2223 - val_accuracy: 0.9217
# Epoch 14/25
# 400/400 [==============================] - 332s 830ms/step - loss: 0.2199 - accuracy: 0.9231 - val_loss: 0.2395 - val_accuracy: 0.9179
# Epoch 15/25
# 400/400 [==============================] - 329s 824ms/step - loss: 0.2046 - accuracy: 0.9321 - val_loss: 0.2218 - val_accuracy: 0.9195
# Epoch 16/25
# 400/400 [==============================] - 332s 830ms/step - loss: 0.2044 - accuracy: 0.9281 - val_loss: 0.1996 - val_accuracy: 0.9258
# Epoch 17/25
# 400/400 [==============================] - 331s 828ms/step - loss: 0.1894 - accuracy: 0.9338 - val_loss: 0.2111 - val_accuracy: 0.9255
# Epoch 18/25
# 400/400 [==============================] - 331s 827ms/step - loss: 0.1814 - accuracy: 0.9373 - val_loss: 0.2126 - val_accuracy: 0.9261
# Epoch 19/25
# 400/400 [==============================] - 333s 831ms/step - loss: 0.1904 - accuracy: 0.9355 - val_loss: 0.1885 - val_accuracy: 0.9334
# Epoch 20/25
# 400/400 [==============================] - 330s 826ms/step - loss: 0.1617 - accuracy: 0.9449 - val_loss: 0.1557 - val_accuracy: 0.9467
# Epoch 21/25
# 400/400 [==============================] - 333s 831ms/step - loss: 0.1728 - accuracy: 0.9405 - val_loss: 0.1424 - val_accuracy: 0.9527
# Epoch 22/25
# 400/400 [==============================] - 331s 828ms/step - loss: 0.1501 - accuracy: 0.9485 - val_loss: 0.2171 - val_accuracy: 0.9195
# Epoch 23/25
# 400/400 [==============================] - 333s 832ms/step - loss: 0.1527 - accuracy: 0.9490 - val_loss: 0.1598 - val_accuracy: 0.9460
# Epoch 24/25
# 400/400 [==============================] - 329s 823ms/step - loss: 0.1461 - accuracy: 0.9496 - val_loss: 0.1467 - val_accuracy: 0.9542
# Epoch 25/25
# 400/400 [==============================] - 332s 831ms/step - loss: 0.1408 - accuracy: 0.9537 - val_loss: 0.1531 - val_accuracy: 0.9514

# %%
# Model Evaluation
scores = model.evaluate(validation_generator)
print("Validation Loss:", scores[0])
print("Validation Accuracy:", scores[1])
# Out:
# 100/100 [==============================] - 45s 452ms/step - loss: 0.1553 - accuracy: 0.9531
# Validation Loss: 0.1552928239107132
# Validation Accuracy: 0.9530956745147705

# %%
# Saving the Model
model.save("tomatoemodelnew.h5")
# Out:
# C:\Users\Kusal\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import os
import matplotlib.pyplot as plt
import random

BATCH_SIZE = 32
IMAGE_SIZE = 256

# Load the saved model
model = tf.keras.models.load_model("tomatoemodelnew.h5")

# Path to the directory containing test images
test_dir = "test_data"

# Get list of test images
test_images = [os.path.join(test_dir, img) for img in os.listdir(test_dir)]

# Mapping class indices to class labels
class_labels = {0: "Potato___Early_blight", 1: "Potato___Late_blight", 2: "Potato___healthy"}  # Update with your actual class labels

# Function to preprocess image
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # Rescale and expand dimensions
    return img, img_array

# Select 20 random images
random_test_images = random.sample(test_images, 20)

# Perform predictions and display images
for img_path in random_test_images:
    img, preprocessed_img = preprocess_image(img_path)
    prediction = model.predict(preprocessed_img)

    # Display image
    plt.imshow(img)
    plt.axis('off')

    # Display prediction
    actual_label = img_path.split(os.path.sep)[-1].split("_")[0]  # Extracting actual label from image file name
    predicted_label = class_labels[np.argmax(prediction)]  # Getting predicted label
    prediction_probabilities = prediction[0]
    print("Image:", img_path)
    print("Actual Label:", actual_label)
    print("Predicted Label:", predicted_label)
    print("Prediction Probabilities:", prediction_probabilities)
    plt.title(f"Actual: {actual_label}, Predicted: {predicted_label}\nProbabilities: {prediction_probabilities}")
    plt.show()

# %%
import numpy as np
from sklearn.metrics import roc_curve, auc

# Plot Loss and Accuracy
plt.figure(figsize=(12, 5))

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Compute predictions and true labels for the validation set
predictions = model.predict(validation_generator)
y_true = validation_generator.classes
# Out:
# 100/100 [==============================] - 45s 447ms/step
